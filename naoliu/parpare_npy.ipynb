# %%
#coding=utf-8

import math 
import os 
import cv2 
import numpy as np 
import scipy.misc
from PIL import Image

# %%
meta_path = './meta_2.csv'

# %%
i = 0
size = 256
list_x =[]
list_y =[]
count = 0

while True:
    with open(meta_path) as f:
        for line in f:
            print(line)
            try:
                train_path, name, M_type, degred= line.split(',')
            except:
                train_path, M_type, degred= line.split(',')
            train_path = train_path + ',' + name
            train_path = train_path.replace("\"","").replace("\"","")
            print(train_path, os.path.exists(train_path)==True)
            if os.path.exists(train_path)==True:
                list_0 = os.listdir(train_path)
                length = len(list_0)
                if length>22:
                    pic_part = []
                    label_part = []
                    for i in range(23):
                        train_pic = train_path + '/' + list_0[i]
                        train = Image.open(train_pic)
                        train = train.resize((size,size))
                        train = np.asarray(train)
                        pic_part.append(train)                        
                    pic_part = np.asarray(pic_part)
                    print(pic_part.shape)
                    list_x.append(pic_part)
                    list_y.append(degred)
                    count += 1 
                    print(count)
                    if count == 5100:
                        print('start')
                        list_x = np.asarray(list_x)
                        print(list_x.shape)
                        list_x = list_x.reshape((count, 23, size, size, 1))
                        list_y = np.asarray(list_y)
                        list_y = list_y.reshape((count, 1))
                        np.save('./x_train.npy', list_x)
                        np.save('./y_train.npy', list_y)
                        print(list_x.shape, list_y.shape)
# Out:
# "/input0/M2/2147/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2147/Ax_T1,Flair_+C True
# (23, 256, 256)
# 1
# "/input0/M2/2394/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2394/Ax_T1,Flair_+C True
# (23, 256, 256)
# 2
# "/input0/M2/1786/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1786/Ax_T1,Flair_+C True
# (23, 256, 256)
# 3
# "/input0/M2/1644/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1644/Ax_T1,Flair_+C True
# (23, 256, 256)
# 4
# "/input0/M2/1884/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1884/Ax_T1,Flair_+C True
# (23, 256, 256)
# 5
# "/input0/M2/1844/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1844/Ax_T1,Flair_+C True
# (23, 256, 256)
# 6
# "/input0/M2/200904/20090413001297/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/200904/20090413001297/Ax_T1,Flair_+C True
# (23, 256, 256)
# 7
# "/input0/M2/200904/20090402001059/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/200904/20090402001059/Ax_T1,Flair_+C True
# (23, 256, 256)
# 8
# "/input0/M2/200904/20090409000845/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/200904/20090409000845/Ax_T1,Flair_+C True
# (23, 256, 256)
# 9
# "/input0/M2/200904/20090416001034/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/200904/20090416001034/Ax_T1,Flair_+C True
# (23, 256, 256)
# 10
# "/input0/M2/1848/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1848/Ax_T1,Flair_+C True
# (23, 256, 256)
# 11
# "/input0/M2/1674/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1674/Ax_T1,Flair_+C True
# (23, 256, 256)
# 12
# "/input0/M2/2122/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2122/Ax_T1,Flair_+C True
# (23, 256, 256)
# 13
# "/input0/M2/1625/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1625/Ax_T1,Flair_+C True
# (23, 256, 256)
# 14
# "/input0/M2/1800/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1800/Ax_T1,Flair_+C True
# (23, 256, 256)
# 15
# "/input0/M2/2396/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2396/Ax_T1,Flair_+C True
# (23, 256, 256)
# 16
# "/input0/M2/1812/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1812/Ax_T1,Flair_+C True
# (23, 256, 256)
# 17
# "/input0/M2/1673/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1673/Ax_T1,Flair_+C True
# (23, 256, 256)
# 18
# "/input0/M2/1985/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1985/Ax_T1,Flair_+C True
# (23, 256, 256)
# 19
# "/input0/M2/2379/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2379/Ax_T1,Flair_+C True
# (23, 256, 256)
# 20
# "/input0/M2/2082/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2082/Ax_T1,Flair_+C True
# (23, 256, 256)
# 21
# "/input0/M2/2157/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2157/Ax_T1,Flair_+C True
# (23, 256, 256)
# 22
# "/input0/M2/1655/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1655/Ax_T1,Flair_+C True
# (23, 256, 256)
# 23
# "/input0/M2/2209/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2209/Ax_T1,Flair_+C True
# (23, 256, 256)
# 24
# "/input0/M2/201302/20130222000877/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201302/20130222000877/Ax_T1,Flair_+C True
# (23, 256, 256)
# 25
# "/input0/M2/201302/20130222000605/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201302/20130222000605/Ax_T1,Flair_+C True
# (23, 256, 256)
# 26
# "/input0/M2/201302/20130225000775/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201302/20130225000775/Ax_T1,Flair_+C True
# (23, 256, 256)
# 27
# "/input0/M2/1622/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1622/Ax_T1,Flair_+C True
# (23, 256, 256)
# 28
# "/input0/M2/201402/20140220000934/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140220000934/Ax_T1,Flair_+C True
# (23, 256, 256)
# 29
# "/input0/M2/201402/20140211001716/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140211001716/Ax_T1,Flair_+C True
# (23, 256, 256)
# 30
# "/input0/M2/201402/20140224001903/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140224001903/Ax_T1,Flair_+C True
# (23, 256, 256)
# 31
# "/input0/M2/201402/20140224001099/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140224001099/Ax_T1,Flair_+C True
# (23, 256, 256)
# 32
# "/input0/M2/201402/20140227000916/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140227000916/Ax_T1,Flair_+C True
# (23, 256, 256)
# 33
# "/input0/M2/201402/20140226001658/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140226001658/Ax_T1,Flair_+C True
# (23, 256, 256)
# 34
# "/input0/M2/201402/20140227000980/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140227000980/Ax_T1,Flair_+C True
# (23, 256, 256)
# 35
# "/input0/M2/201402/20140227000791/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140227000791/Ax_T1,Flair_+C True
# (23, 256, 256)
# 36
# "/input0/M2/201402/20140210000685/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140210000685/Ax_T1,Flair_+C True
# (23, 256, 256)
# 37
# "/input0/M2/201402/20140228001488/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140228001488/Ax_T1,Flair_+C True
# (23, 256, 256)
# 38
# "/input0/M2/201402/20140210001370/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140210001370/Ax_T1,Flair_+C True
# (23, 256, 256)
# 39
# "/input0/M2/201402/20140228000904/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140228000904/Ax_T1,Flair_+C True
# (23, 256, 256)
# 40
# "/input0/M2/201402/20140208001384/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140208001384/Ax_T1,Flair_+C True
# (23, 256, 256)
# 41
# "/input0/M2/201402/20140226001241/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140226001241/Ax_T1,Flair_+C True
# (23, 256, 256)
# 42
# "/input0/M2/201402/20140211000823/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201402/20140211000823/Ax_T1,Flair_+C True
# (23, 256, 256)
# 43
# "/input0/M2/200906/20090615001144/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/200906/20090615001144/Ax_T1,Flair_+C True
# (23, 256, 256)
# 44
# "/input0/M2/200906/20090601000073/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/200906/20090601000073/Ax_T1,Flair_+C True
# (23, 256, 256)
# 45
# "/input0/M2/200906/20090602001148/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/200906/20090602001148/Ax_T1,Flair_+C True
# (23, 256, 256)
# 46
# "/input0/M2/1889/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1889/Ax_T1,Flair_+C True
# (23, 256, 256)
# 47
# "/input0/M2/2173/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2173/Ax_T1,Flair_+C True
# "/input0/M2/2101/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2101/Ax_T1,Flair_+C True
# (23, 256, 256)
# 48
# "/input0/M2/201008/20100820001270/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100820001270/Ax_T1,Flair_+C True
# (23, 256, 256)
# 49
# "/input0/M2/201008/20100811002332/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100811002332/Ax_T1,Flair_+C True
# (23, 256, 256)
# 50
# "/input0/M2/201008/20100802001507/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100802001507/Ax_T1,Flair_+C True
# (23, 256, 256)
# 51
# "/input0/M2/201008/20100816001735/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100816001735/Ax_T1,Flair_+C True
# (23, 256, 256)
# 52
# "/input0/M2/201008/20100809000054/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100809000054/Ax_T1,Flair_+C True
# "/input0/M2/201008/20100820002052/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100820002052/Ax_T1,Flair_+C True
# (23, 256, 256)
# 53
# "/input0/M2/201008/20100816000539/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100816000539/Ax_T1,Flair_+C True
# (23, 256, 256)
# 54
# "/input0/M2/201008/20100808000054/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100808000054/Ax_T1,Flair_+C True
# (23, 256, 256)
# 55
# "/input0/M2/201008/20100828000234/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100828000234/Ax_T1,Flair_+C True
# (23, 256, 256)
# 56
# "/input0/M2/201008/20100819001931/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/201008/20100819001931/Ax_T1,Flair_+C True
# (23, 256, 256)
# 57
# /input0/M2/2019/OAx_T1+C,M2,0
#
# /input0/M2/2019/OAx_T1+C,Flair_+C False
# "/input0/M2/1715/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1715/Ax_T1,Flair_+C True
# (23, 256, 256)
# 58
# "/input0/M2/1991/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1991/Ax_T1,Flair_+C True
# (23, 256, 256)
# 59
# "/input0/M2/1654/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1654/Ax_T1,Flair_+C True
# (23, 256, 256)
# 60
# "/input0/M2/2051/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2051/Ax_T1,Flair_+C True
# (23, 256, 256)
# 61
# /input0/M2/2018/OAx_T1+C,M2,0
#
# /input0/M2/2018/OAx_T1+C,Flair_+C False
# "/input0/M2/1859/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1859/Ax_T1,Flair_+C True
# (23, 256, 256)
# 62
# "/input0/M2/1907/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1907/Ax_T1,Flair_+C True
# (23, 256, 256)
# 63
# "/input0/M2/2012/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2012/Ax_T1,Flair_+C True
# (23, 256, 256)
# 64
# "/input0/M2/2290/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2290/Ax_T1,Flair_+C True
# (23, 256, 256)
# 65
# "/input0/M2/1910/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1910/Ax_T1,Flair_+C True
# (23, 256, 256)
# 66
# /input0/M2/1968/OAx_T1+C,M2,0
#
# /input0/M2/1968/OAx_T1+C,Flair_+C False
# "/input0/M2/1931/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1931/Ax_T1,Flair_+C True
# (23, 256, 256)
# 67
# "/input0/M2/1930/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1930/Ax_T1,Flair_+C True
# (23, 256, 256)
# 68
# "/input0/M2/1970/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1970/Ax_T1,Flair_+C True
# (23, 256, 256)
# 69
# "/input0/M2/1838/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1838/Ax_T1,Flair_+C True
# (23, 256, 256)
# 70
# /input0/M2/2368/OAx_T1+C,M2,0
#
# /input0/M2/2368/OAx_T1+C,Flair_+C False
# "/input0/M2/1855/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1855/Ax_T1,Flair_+C True
# "/input0/M2/1719/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/1719/Ax_T1,Flair_+C True
# (23, 256, 256)
# 71
# /input0/M2/2243/OAx_T1+C,M2,0
#
# /input0/M2/2243/OAx_T1+C,Flair_+C False
# "/input0/M2/2313/Ax_T1,Flair_+C",M2,0
#
# /input0/M2/2313/Ax_T1,Flair_+C True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7cfc3c292315> in <module>()
#      25                         train_pic = train_path + '/' + list_0[i]
#      26                         train = Image.open(train_pic)
# ---> 27                         train = train.resize((size,size))
#      28                         train = np.asarray(train)
#      29                         pic_part.append(train)
#
# /usr/local/lib/python3.6/site-packages/PIL/Image.py in resize(self, size, resample, box)
#    1761             return self.convert('RGBa').resize(size, resample, box).convert('RGBA')
#    1762
# -> 1763         self.load()
#    1764
#    1765         return self._new(self.im.resize(size, resample, box))
#
# /usr/local/lib/python3.6/site-packages/PIL/ImageFile.py in load(self)
#     233
#     234                             b = b + s
# --> 235                             n, err_code = decoder.decode(b)
#     236                             if n < 0:
#     237                                 break
#
# KeyboardInterrupt:
